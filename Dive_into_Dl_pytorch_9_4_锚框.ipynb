# %% [markdown]
# <a href="https://colab.research.google.com/github/sakurasakura1996/Pytorch-start-learning/blob/master/Dive_into_Dl_pytorch_9_4_%E9%94%9A%E6%A1%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 锚框是针对图像中每个像素点生成多个大小和宽高比不同的边界框。
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
# %matplotlib inline
import
